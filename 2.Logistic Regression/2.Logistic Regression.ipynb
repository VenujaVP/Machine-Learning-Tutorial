# %% [markdown]
# <h2 style='color:Goldenrod' align='center'>Logistic Regression Example</h2>

# %% [markdown]
# <h2 style='color:green' align='left'>(1) Binary Logistic Regression Example</h2>

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [raw]
# #Process to generate sample values involve to SPAM NOT SPAM in MASSAGES
# def random_yn():
#     return random.choice(["Yes", "No"])
#
# data = []
#
# # Generate remaining rows
# for _ in range(94):
#     caps = random_yn()
#     unknown = random_yn()
#     # Increase chance of spam with CAPS and unknown sender (but not guaranteed)
#     spam = 1 if (caps == "Yes" and unknown == "Yes") else random.randint(0, 1)
# #add gen values to data list
#     data.append([caps, unknown, spam])
#
# #Spam (0 = Not Spam, 1 = Spam)
# #create table using pandas
# df = pd.DataFrame(data, columns=['subject', 'Sender_unknown', 'Spam'])
# df

# %% [raw]
# #save file as csv to givan location
# df.to_csv(r'C:\MIT\ML\github\2.Logistic Regression\msg_spam.csv',index = False)

# %%
#Load saved csv file
data = pd.read_csv('msg_spam.csv')

# %%
#Strip whitespace from column names.
data.columns = data.columns.str.strip()

# %%
#we want ro check which values avalable before encode catg values
#Check avalable distint values in Spam
data['Spam'].value_counts()
# Out:
# Spam
# 0    48
# 1    46
# Name: count, dtype: int64

# %%
#Check avalable distint values in subject
data['subject'].value_counts()
# Out:
# subject
# No     56
# Yes    38
# Name: count, dtype: int64

# %%
#Check avalable distint values in Sender_unknown
data['Sender_unknown'].value_counts()
# Out:
# Sender_unknown
# Yes    47
# No     47
# Name: count, dtype: int64

# %%
# Data Visualization
# Plot the distribution of the target variable
plt.figure(figsize=(6, 4))
sns.countplot(x='Spam', hue='subject',  data=data)
plt.title('Distribution of Spam vs Not Spam')
plt.show()

# %%
# Data Visualization
# Plot the distribution of the target variable
plt.figure(figsize=(6, 4))
sns.countplot(x='Spam', hue='Sender_unknown',  data=data)
plt.title('Distribution of Spam vs Not Spam')
plt.show()

# %%
# Convert categorical variables to numeric
data['subject'] = data['subject'].map({'Yes': 1, 'No': 0})
data['Sender_unknown'] = data['Sender_unknown'].map({'Yes': 1, 'No': 0})

# %%
# Split data into features and target
X2 = data[['subject', 'Sender_unknown']]
X = data[['Sender_unknown']]
y = data['Spam']

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.5862068965517241
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54        12
#            1       0.67      0.59      0.62        17
#
#     accuracy                           0.59        29
#    macro avg       0.58      0.59      0.58        29
# weighted avg       0.60      0.59      0.59        29

# %%
# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Spam', 'Spam'], yticklabels=['Not Spam', 'Spam'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
#  <h2 style='color:green' align='left'>(2) Multiclass Logistic Regression Example</h2>

# %%
# Split data into training and test sets
X2_train, X2_test, y_train, y_test = train_test_split(X2, y, test_size=0.3, random_state=42)

# Create and train the logistic regression model
model_2 = LogisticRegression()
model_2.fit(X2_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions
y2_pred = model_2.predict(X2_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y2_pred)
report = classification_report(y_test, y2_pred)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.5862068965517241
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54        12
#            1       0.67      0.59      0.62        17
#
#     accuracy                           0.59        29
#    macro avg       0.58      0.59      0.58        29
# weighted avg       0.60      0.59      0.59        29
